# %%
import os, gc, pickle, datetime, scipy.sparse,random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from colorama import Fore, Back, Style

import sklearn 
from sklearn.model_selection import GroupKFold,train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD,PCA
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
from cycler import cycler
from IPython.display import display

import scipy.sparse
from tqdm.notebook import tqdm

DATA_DIR = "./"
FP_CELL_METADATA = os.path.join(DATA_DIR,"metadata.csv")

FP_CITE_TRAIN_INPUTS = os.path.join(DATA_DIR,"train_cite_inputs.h5")
FP_CITE_TRAIN_TARGETS = os.path.join(DATA_DIR,"train_cite_targets.h5")
FP_CITE_TEST_INPUTS = os.path.join(DATA_DIR,"test_cite_inputs.h5")

FP_SUBMISSION = os.path.join(DATA_DIR,"sample_submission.csv")
FP_EVALUATION_IDS = os.path.join(DATA_DIR,"evaluation_ids.csv")

VERBOSE = 0

# %%
import math

import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow_addons as tfa
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, LearningRateScheduler, EarlyStopping
from tensorflow.keras.layers import Dense, Input, Concatenate, Dropout, BatchNormalization, AlphaDropout
import keras_tuner
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Standardize
def std(x):
    empty_list = []
    for item in x:
        empty_list.append((item - np.mean(item)) / np.std(item))
    return np.array(empty_list)

# %%
import anndata as ad

# %%
def seed_tensorflow(seed=1):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

# %%
# constant_cols = list(X.columns[(X == 0).all(axis=0).values]) + list(X_test.columns[(X_test == 0).all(axis=0).values])
constant_cols = ['ENSG00000003137_CYP26B1', 'ENSG00000004848_ARX', 'ENSG00000006606_CCL26', 'ENSG00000010379_SLC6A13', 'ENSG00000010932_FMO1', 'ENSG00000017427_IGF1', 'ENSG00000022355_GABRA1', 'ENSG00000041982_TNC', 'ENSG00000060709_RIMBP2', 'ENSG00000064886_CHI3L2', 'ENSG00000065717_TLE2', 'ENSG00000067798_NAV3', 'ENSG00000069535_MAOB', 'ENSG00000073598_FNDC8', 'ENSG00000074219_TEAD2', 'ENSG00000074964_ARHGEF10L', 'ENSG00000077264_PAK3', 'ENSG00000078053_AMPH', 'ENSG00000082684_SEMA5B', 'ENSG00000083857_FAT1', 'ENSG00000084628_NKAIN1', 'ENSG00000084734_GCKR', 'ENSG00000086967_MYBPC2', 'ENSG00000087258_GNAO1', 'ENSG00000089505_CMTM1', 'ENSG00000091129_NRCAM', 'ENSG00000091986_CCDC80', 'ENSG00000092377_TBL1Y', 'ENSG00000092969_TGFB2', 'ENSG00000095397_WHRN', 'ENSG00000095970_TREM2', 'ENSG00000099715_PCDH11Y', 'ENSG00000100197_CYP2D6', 'ENSG00000100218_RSPH14', 'ENSG00000100311_PDGFB', 'ENSG00000100362_PVALB', 'ENSG00000100373_UPK3A', 'ENSG00000100625_SIX4', 'ENSG00000100867_DHRS2', 'ENSG00000100985_MMP9', 'ENSG00000101197_BIRC7', 'ENSG00000101298_SNPH', 'ENSG00000102387_TAF7L', 'ENSG00000103034_NDRG4', 'ENSG00000104059_FAM189A1', 'ENSG00000104112_SCG3', 'ENSG00
 'ENSG00000163565_IFI16',
 'ENSG00000117450_PRDX1',
 'ENSG00000124570_SERPINB6',
 'ENSG00000112077_RHAG',
 'ENSG00000051523_CYBA',
 'ENSG00000107130_NCS1',
 'ENSG00000055118_KCNH2',
 'ENSG00000029534_ANK1',
 'ENSG00000169567_HINT1',
 'ENSG00000142089_IFITM3',
 'ENSG00000139278_GLIPR1',
 'ENSG00000142227_EMP3',
 'ENSG00000076662_ICAM3',
 'ENSG00000143627_PKLR',
 'ENSG00000130755_GMFG',
 'ENSG00000160593_JAML',
 'ENSG00000095932_SMIM24',
 'ENSG00000197956_S100A6',
 'ENSG00000171476_HOPX',
 'ENSG00000116675_DNAJC6',
 'ENSG00000100448_CTSG',
 'ENSG00000100368_CSF2RB',
 'ENSG00000047648_ARHGAP6',
 'ENSG00000198918_RPL39',
 'ENSG00000196154_S100A4',
 'ENSG00000233968_AL157895.1',
 'ENSG00000137642_SORL1',
 'ENSG00000133816_MICAL2',
 'ENSG00000130208_APOC1',
 'ENSG00000105610_KLF1']
print('important columns ',len(important_cols))
# Out:
# Constant cols: 1194
# important columns  84

# %%
metadata_df = pd.read_csv(FP_CELL_METADATA, index_col = 'cell_id')
metadata_df = metadata_df[metadata_df.technology == "citeseq"]

# Read train and convert to sparse matrix
# X = pd.read_hdf(FP_CITE_TRAIN_INPUTS)
X = pd.read_hdf(FP_CITE_TRAIN_INPUTS).drop(columns = constant_cols)
# X = pd.read_csv("/gpfs/ysm/home/tl688/scrnahpc/tl688/openproblems/scGNN/outputdir/train_protein_recon.csv",index_col=0).T.drop(columns = constant_cols)
cell_index = X.index
meta = metadata_df.reindex(cell_index)
X0 = X[important_cols].values

del X
gc.collect()


# Read test and convert to sparse matrix
# Xt = pd.read_hdf(FP_CITE_TEST_INPUTS)
Xt = pd.read_hdf(FP_CITE_TEST_INPUTS).drop(columns = constant_cols)
cell_index_test = Xt.index
meta_test = metadata_df.reindex(cell_index_test)
X0t = Xt[important_cols].values

del Xt
gc.collect()

st = StandardScaler()
X0 = st.fit_transform(X0)
X0t = st.transform(X0t)

print(f'X0 shape {X0.shape} X0t shape {X0t.shape}')
# Out:
# X0 shape (70988, 84) X0t shape (48663, 84)

# %%
with open('./input/targets-multiome-sparse-scaled/train_cite_512.pkl','rb') as f: X = pickle.load(f)
with open('./input/targets-multiome-sparse-scaled/test_cite_512.pkl','rb') as f: Xt = pickle.load(f)

X.shape, Xt.shape


# with open('./input/targets-multiome-sparse-scaled/train_Citeseq_truncated_512.pkl','rb') as f: X = pickle.load(f)
# with open('./input/targets-multiome-sparse-scaled/test_Citeseq_truncated_512.pkl','rb') as f: Xt = pickle.load(f)

# X.shape, Xt.shape
# Out:
# ((70988, 512), (48663, 512))

# %%
X
# Out:
# array([[-2.3822762e+02,  3.1855104e+01,  2.3049294e+01, ...,
#         -1.3715878e+00, -2.8723223e+00, -1.4102858e+00],
#        [-2.3365659e+02,  4.0229019e+01,  1.9437603e+01, ...,
#          3.7163601e+00,  4.1906461e-01, -1.3358747e+00],
#        [-2.5014233e+02, -4.6703153e+00,  9.4395075e+00, ...,
#         -3.6248217e+00,  2.4677904e+00,  3.7641099e-01],
#        ...,
#        [-2.6739429e+02, -1.4522221e+01,  8.5594721e+00, ...,
#          2.5515324e-01,  2.7128370e+00, -1.5232078e+00],
#        [-2.7380966e+02, -2.3930012e+01, -3.1388956e+01, ...,
#         -2.1867669e+00, -3.8604670e+00,  5.6192124e-01],
#        [-2.3833578e+02,  1.1786343e+01,  1.1732360e+01, ...,
#         -3.7178817e+00,  8.2002485e-01, -1.9139581e+00]], dtype=float32)

# %%
Y = pd.read_hdf(FP_CITE_TRAIN_TARGETS)
Y = Y.values
Y -= Y.mean(axis=1).reshape(-1, 1)
Y /= Y.std(axis=1).reshape(-1, 1)
Y.shape
# Out:
# (70988, 140)

# %%
feature_number_pca = 66

# %%
X = np.hstack((X[:,:feature_number_pca],X0))
X.shape
# Out:
# (70988, 150)

# %%
X
# Out:
# array([[-238.22762   ,   31.855104  ,   23.049294  , ...,   -0.364857  ,
#           -0.61251414,   -0.68285155],
#        [-233.65659   ,   40.22902   ,   19.437603  , ...,   -0.364857  ,
#           -0.61251414,   -0.68285155],
#        [-250.14233   ,   -4.6703153 ,    9.4395075 , ...,   -0.364857  ,
#            2.0863745 ,    1.9733372 ],
#        ...,
#        [-267.3943    ,  -14.522221  ,    8.559472  , ...,    2.6505954 ,
#            1.9836951 ,    1.6599795 ],
#        [-273.80966   ,  -23.930012  ,  -31.388956  , ...,    3.2577517 ,
#           -0.61251414,   -0.68285155],
#        [-238.33578   ,   11.786343  ,   11.73236   , ...,    2.94607   ,
#           -0.61251414,    1.6039475 ]], dtype=float32)

# %%
metadata_df
# Out:
#               day  donor cell_type technology
# cell_id
# c2150f55becb    2  27678       HSC    citeseq
# 65b7edf8a4da    2  27678       HSC    citeseq
# c1b26cb1057b    2  27678      EryP    citeseq
# 917168fa6f83    2  27678      NeuP    citeseq
# 2b29feeca86d    2  27678      EryP    citeseq
# ...           ...    ...       ...        ...
# a9b4d99f1f50    7  31800       HSC    citeseq
# 0e2c1d0782af    7  31800       HSC    citeseq
# a3cbc5aa0ec3    7  31800       MkP    citeseq
# 75b350243add    7  31800      EryP    citeseq
# ad5a949989b2    7  31800      EryP    citeseq
#
# [119651 rows x 4 columns]

# %%
ct_list = metadata_df.cell_type

# %%
dict_celltype = {}
count = 0
for i in sorted(list(set(ct_list.values))):
    dict_celltype[i] = count 
    count += 1

# %%
dict_celltype
# Out:
# {'BP': 0, 'EryP': 1, 'HSC': 2, 'MasP': 3, 'MkP': 4, 'MoP': 5, 'NeuP': 6}

# %%
celltype_new = [dict_celltype[i] for i in meta.cell_type.values]

# %%
meta["cell_type_bin"] = celltype_new

# %%
cell_type_class = meta["cell_type_bin"].values

# %%
def correlation_score(y_true, y_pred):
    if type(y_true) == pd.DataFrame: y_true = y_true.values
    if type(y_pred) == pd.DataFrame: y_pred = y_pred.values
    corrsum = 0
    for i in range(len(y_true)):
        corrsum += np.corrcoef(y_true[i], y_pred[i])[1, 0]
    return corrsum / len(y_true)

def negative_correlation_loss(y_true, y_pred):
    
    y_true_label = y_true[:,140:]
    y_pred_label =  y_pred[:,140:]
    
    y_true = y_true[:,:140]
    y_pred = y_pred[:,:140]
    
    my = K.mean(tf.convert_to_tensor(y_pred), axis=1)
    my = tf.tile(tf.expand_dims(my, axis=1), (1, y_true.shape[1]))
    ym = y_pred - my
    r_num = K.sum(tf.multiply(y_true, ym), axis=1)
    r_den = tf.sqrt(K.sum(K.square(ym), axis=1) * float(y_true.shape[-1]))
    r = tf.reduce_mean(r_num / r_den)
    return - r + tf.keras.losses.SparseCategoricalCrossentropy()(y_true_label,  y_pred_label)

# %%
LR_START = 5e-3#5e-3
BATCH_SIZE = 512

def create_model():
    
    reg1 = 9.613e-06
    reg2 = 1e-07
    REG1 = tf.keras.regularizers.l2(reg1)
    REG2 = tf.keras.regularizers.l2(reg2)
    DROP = 0.2

    activation = 'selu'
    inputs = Input(shape =(X.shape[1],))

    x0 = Dense(512, 
              kernel_regularizer = REG1,
              activation = activation,
             )(inputs)
    

    x0 = Dropout(DROP)(x0)
    
    
    
    x1 = Dense(512, 
               kernel_regularizer = REG1,
               activation = activation,
             )(x0)

    x1 = Dropout(DROP)(x1)
    
    
    
    x2 = Dense(512, 
               kernel_regularizer = REG1,
               activation = activation,
             )(x1+x0) 
    

    x2 = Dropout(DROP)(x2)

    
    x3 = Dense(Y.shape[1],
               kernel_regularizer = REG1,
               activation = activation,
             )(x2+x1)
    

    x3 = Dropout(DROP)(x3)

    x = Concatenate()([
                x0, 
                x1, 
                x2, 
                x3
                ])
    
    x = Dense(Y.shape[1], 
                kernel_regularizer = REG2,
                activation="linear",
                )(x)
    
    x_out = Dense(Y.shape[1], 
                kernel_regularizer = REG2,
                activation=activation,
                )(inputs)

    x = x + x_out
    
    
    x00 = Dense(64, 
              activation = activation,
             )(x)
    
    
    x10 = Dense(32, 
               activation = activation,
             )(x00)


    
    x20 = Dense(7, 
               activation = "softmax",
             )(x10)
        
    
        
    model = Model(inputs, Concatenate()([x,x20]))
    

    return model

# %%
meta.cell_type
# Out:
# cell_id
# 45006fe3e4c8     HSC
# d02759a80ba2     HSC
# c016c6b0efa5    EryP
# ba7f733a4f75    NeuP
# fbcf2443ffb2    EryP
#                 ...
# 650ee456f0f3     HSC
# cc506e7707f5    EryP
# a91f1b55a520    EryP
# 3a9882c98205    MasP
# c91b6b2ccd3d    EryP
# Name: cell_type, Length: 70988, dtype: object

# %%
np.hstack([Y[idx_tr], cell_type_class[idx_tr].reshape(-1,1)])
# Out:
# array([[ 0.09460453, -0.16236241, -0.40533188, ...,  0.38325769,
#         -0.19745257,  2.        ],
#        [-0.25125083, -0.35797054, -0.16268902, ...,  0.40262994,
#          0.21424626,  2.        ],
#        [-0.50453472, -0.52717918, -0.66611427, ...,  0.98586214,
#          0.60952032,  1.        ],
#        ...,
#        [-0.21439953, -0.42171365, -0.15420543, ...,  1.36944079,
#          0.39634082,  1.        ],
#        [-0.59204561, -0.85295653, -0.36310589, ...,  0.1609816 ,
#          0.75275707,  3.        ],
#        [-0.64900035, -0.61859208, -0.27466986, ...,  1.65784419,
#          0.4573473 ,  1.        ]])

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

EPOCHS = 1100
N_SPLITS = 3

pred_train = np.zeros((Y.shape[0],Y.shape[1]))

seed_tensorflow(1)
score_list = []
kf = GroupKFold(n_splits=N_SPLITS)
# kf = sklearn.model_selection.KFold(5)
score_list = []

for fold, (idx_tr, idx_va) in enumerate(kf.split(X, groups=meta.donor)):
    start_time = datetime.datetime.now()
    model = None
    gc.collect()
    
    X_tr = X[idx_tr]
    y_tr = Y[idx_tr]
    X_va = X[idx_va]
    y_va = Y[idx_va]
    
    y_tr = np.hstack([Y[idx_tr], cell_type_class[idx_tr].reshape(-1,1)])
    y_va = np.hstack([Y[idx_va], cell_type_class[idx_va].reshape(-1,1)])

    lr = ReduceLROnPlateau(
                    monitor = "val_loss",
                    factor = 0.9, 
                    patience = 4, 
                    verbose = VERBOSE)
    
    
    es = EarlyStopping(
                    monitor = "val_loss",
                    patience = 100, 
                    verbose = VERBOSE,
                    mode = "min", 
                    restore_best_weights = True)

    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
                    filepath = './citeseq',
                    save_weights_only = True,
                    monitor = 'val_loss',
                    mode = 'min',
                    save_best_only = True)

    callbacks = [   lr, 
                    es, 
                    model_checkpoint_callback
                    ]
    
    model = create_model()
    
    
    model.compile(
                optimizer = tfa.optimizers.AdaBelief(learning_rate = LR_START),
                metrics = [negative_correlation_loss],
                loss = negative_correlation_loss
                 )
    # Training
    model.fit(
                X_tr,
                y_tr, 
                validation_data=(
                                X_va,
                                y_va), 
                epochs = EPOCHS,
                verbose = VERBOSE,
                batch_size = BATCH_SIZE,
                shuffle = True,
                callbacks = callbacks)

    del X_tr, y_tr 
    gc.collect()
    
    model.load_weights('./citeseq')
    model.save(f"./submissions/model_{fold}")
    print('model saved')
    
    #  Model validation
    y_va_pred = model.predict(X_va)
    print("yes")
    corrscore = correlation_score(y_va[:,0:140], y_va_pred[:,0:140])
    pred_train[idx_va] = y_va_pred[:,0:140]
    
    print(f"Fold {fold}, correlation =  {corrscore:.5f}")
    del X_va, y_va, y_va_pred
    gc.collect()
    score_list.append(corrscore)

# Show overall score

print(f"{Fore.GREEN}{Style.BRIGHT}Mean corr = {np.array(score_list).mean():.5f}{Style.RESET_ALL}")
score_total = correlation_score(Y, pred_train[:,:140])
print(f"{Fore.BLUE}{Style.BRIGHT}Oof corr   = {score_total:.5f}{Style.RESET_ALL}")



# # multi layer opt
# import warnings
# warnings.filterwarnings("ignore")

# EPOCHS = 1100
# N_SPLITS = 3

# pred_train = np.zeros((Y.shape[0],Y.shape[1]))

# # np.random.seed(1)
# # tf.random.set_seed(1)
# seed_tensorflow()
# score_list = []
# kf = GroupKFold(n_splits=N_SPLITS)
# score_list = []

# for fold, (idx_tr, idx_va) in enumerate(kf.split(X, groups=meta.donor)):
#     start_time = datetime.datetime.now()
#     model = None
#     gc.collect()
    
#     X_tr = X[idx_tr]
#     y_tr = Y[idx_tr]
#     X_va = X[idx_va]
#     y_va = Y[idx_va]

#     lr = ReduceLROnPlateau(
#                     monitor = "val_loss",
#                     factor = 0.9, 
#                     patience = 4, 
#                     verbose = VERBOSE)

#     es = EarlyStopping(
#                     monitor = "val_loss",
#                     patience = 100, 
#                     verbose = VERBOSE,
#                     mode = "min", 
#                     restore_best_weights = True)

#     model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#                     filepath = './citeseq',
#                     save_weights_only = True,
#                     monitor = 'val_loss',
#                     mode = 'min',
#                     save_best_only = True)

#     callbacks = [   #lr, 
#                     es, 
#                     model_checkpoint_callback
#                     ]
    
#     model = create_model()
    
    
#     optimizers = [
#     tfa.optimizers.AdaBelief(learning_rate=5e-3),
#     tfa.optimizers.AdaBelief(learning_rate=5e-2)
#     ]
    
#     optimizers_and_layers = [(optimizers[0], model.layers[0:10]), (optimizers[1], model.layers[10:])]
#     optimizer_multi = tfa.optimizers.MultiOptimizer(optimizers_and_layers)
    
#     model.compile(
#                 optimizer = optimizer_multi,
#                 metrics = [negative_correlation_loss],
#                 loss = negative_correlation_loss
#                  )
#     # Training
#     model.fit(
#                 X_tr,
#                 y_tr, 
#                 validation_data=(
#                                 X_va,
#                                 y_va), 
#                 epochs = EPOCHS,
#                 verbose = VERBOSE,
#                 batch_size = BATCH_SIZE,
#                 shuffle = True,
#                 callbacks = callbacks)

#     del X_tr, y_tr 
#     gc.collect()
    
#     model.load_weights('./citeseq')
#     model.save(f"./submissions/model_{fold}")
#     print('model saved')
    
#     #  Model validation
#     y_va_pred = model.predict(X_va)
#     corrscore = correlation_score(y_va, y_va_pred)
#     pred_train[idx_va] = y_va_pred
    
#     print(f"Fold {fold}, correlation =  {corrscore:.5f}")
#     del X_va, y_va, y_va_pred
#     gc.collect()
#     score_list.append(corrscore)

# # Show overall score

# print(f"{Fore.GREEN}{Style.BRIGHT}Mean corr = {np.array(score_list).mean():.5f}{Style.RESET_ALL}")
# score_total = correlation_score(Y, pred_train)
# print(f"{Fore.BLUE}{Style.BRIGHT}Oof corr   = {score_total:.5f}{Style.RESET_ALL}")
# Out:
# INFO:tensorflow:Assets written to: ./submissions/model_0/assets
# model saved
# 776/776 [==============================] - 1s 1ms/step
# yes
# Fold 0, correlation =  0.89181
# INFO:tensorflow:Assets written to: ./submissions/model_1/assets
# model saved
# 750/750 [==============================] - 1s 2ms/step
# yes
# Fold 1, correlation =  0.80785
# INFO:tensorflow:Assets written to: ./submissions/model_2/assets
# model saved
# 694/694 [==============================] - 1s 2ms/step
# yes
# Fold 2, correlation =  0.85621
# Mean corr = 0.85196
# Oof corr   = 0.85231
# CPU times: user 5min 32s, sys: 7.13 s, total: 5min 39s
# Wall time: 9min 47s

# %%
# Xt = np.hstack((Xt[:,:feature_number_pca],X0t))
# Xt.shape
Xt = np.hstack((Xt[:,:feature_number_pca],X0t, X0t_celltype))
Xt.shape
# Out:
# (48663, 168)

# %%
test_list = np.array([[1,2,3],[3,2,1],[1,0,1]])
std(test_list)
# Out:
# array([[-1.22474487,  0.        ,  1.22474487],
#        [ 1.22474487,  0.        , -1.22474487],
#        [ 0.70710678, -1.41421356,  0.70710678]])

# %%
test_list
# Out:
# array([[1, 2, 3],
#        [3, 2, 1],
#        [1, 0, 1]])

# %%
test_pred = np.zeros((len(Xt), 140), dtype=np.float32)
for fold in range(N_SPLITS):
    print(f"Predicting with fold {fold}")
    model = load_model(f"./submissions/model_{fold}",
                       custom_objects={'negative_correlation_loss': negative_correlation_loss})
    test_pred += model.predict(Xt)

print(len(test_pred))
# Copy the targets for the data leak but useless since the change in the public LB...
test_pred[:7476] = Y[:7476]


# from Juan Smith Perera to complete with the Multiome part :
# submission = pd.read_csv('submission_lolo_1.csv',index_col='row_id', squeeze=True)

print(test_pred)

test_pred = std(test_pred)

print(test_pred)
# submission = pd.read_csv("/ysm-gpfs/pi/zhao/tl688/openproblems/submission_10_combine.csv",index_col='row_id', squeeze=True)
# submission.iloc[:len(test_pred.ravel())] = test_pred.ravel()
# assert not submission.isna().any()

# submission.to_csv('submission_onebestcite.csv')
# display(submission)
# Out:
# Predicting with fold 0
# 1521/1521 [==============================] - 2s 1ms/step
# Predicting with fold 1
# 1521/1521 [==============================] - 2s 1ms/step
# Predicting with fold 2
# 1521/1521 [==============================] - 2s 1ms/step
# 48663
# [[ 9.4604529e-02 -1.6236241e-01 -4.0533188e-01 ... -2.6049733e-01
#    3.8325769e-01 -1.9745257e-01]
#  [-2.5125083e-01 -3.5797054e-01 -1.6268902e-01 ... -1.9555242e-01
#    4.0262994e-01  2.1424626e-01]
#  [-5.0453472e-01 -5.2717918e-01 -6.6611427e-01 ... -7.8993803e-01
#    9.8586214e-01  6.0952032e-01]
#  ...
#  [-8.1554993e+01 -3.1155190e+01 -5.0684601e+01 ... -7.5564728e+01
#   -5.1838104e+01  5.2822746e+01]
#  [-8.0224876e+01 -6.4099884e+01 -4.0413280e+01 ... -7.7787079e+01
#    1.9851367e+02  8.0069778e+01]
#  [-7.2409058e+01 -5.8891174e+01 -3.9310787e+01 ... -7.4846786e+01
#    2.4202838e+02  9.9897881e+01]]
# [[ 0.09460448 -0.16236246 -0.40533194 ... -0.2604974   0.38325763
#   -0.19745262]
#  [-0.2512508  -0.3579705  -0.16268899 ... -0.1955524   0.40262997
#    0.21424629]
#  [-0.50453466 -0.5271791  -0.6661142  ... -0.789938    0.9858622
#    0.6095204 ]
#  ...
#  [-0.39562437 -0.07664843 -0.20024836 ... -0.3577125  -0.2075488
#    0.45484054]
#  [-0.6060044  -0.4580055  -0.24060436 ... -0.5836297   1.9523225
#    0.8652171 ]
#  [-0.5492751  -0.42562565 -0.2465219  ... -0.57157326  2.3269155
#    1.0268337 ]]

# %%
submission = pd.read_csv("/ysm-gpfs/pi/zhao/tl688/openproblems/submission_testourcite.csv",index_col='row_id', squeeze=True)
submission.iloc[:len(test_pred.ravel())] = test_pred.ravel()
assert not submission.isna().any()

submission.to_csv('submission_onebestcite_updatekfold.csv')
display(submission)
# Out:
# row_id
# 0           0.094604
# 1          -0.162362
# 2          -0.405332
# 3          -0.302582
# 4           1.114355
#               ...
# 65744175    2.777528
# 65744176   -0.369145
# 65744177   -0.367802
# 65744178    0.135783
# 65744179    2.558738
# Name: target, Length: 65744180, dtype: float64

# %%
test_pred
# Out:
# array([[ 9.4604529e-02, -1.6236241e-01, -4.0533188e-01, ...,
#         -2.6049733e-01,  3.8325769e-01, -1.9745257e-01],
#        [-2.5125083e-01, -3.5797054e-01, -1.6268902e-01, ...,
#         -1.9555242e-01,  4.0262994e-01,  2.1424626e-01],
#        [-5.0453472e-01, -5.2717918e-01, -6.6611427e-01, ...,
#         -7.8993803e-01,  9.8586214e-01,  6.0952032e-01],
#        ...,
#        [-1.0985884e+02, -3.9327122e+01, -6.5025253e+01, ...,
#         -9.2144600e+01, -7.7501633e+01,  4.6865902e+01],
#        [-9.2803215e+01, -7.8483650e+01, -5.0464352e+01, ...,
#         -8.5875710e+01,  1.9630319e+02,  9.0480896e+01],
#        [-8.9690689e+01, -7.3419548e+01, -4.7673729e+01, ...,
#         -7.9953278e+01,  2.3358974e+02,  1.0799841e+02]], dtype=float32)

# %%
submission_cite = pd.read_csv('submission_813.csv',index_col='row_id', squeeze=True)
submission_multiome = pd.read_csv("standard_ensemble_812.csv", index_col='row_id', squeeze=True)

# %%
submission_cite.values

# %%
# submission_multiome.iloc[0:6812820] = submission_cite.iloc[0:6812820]

# %%
# submission_multiome.to_csv("submission_ensemble_cite_standardmulti.csv")

# %%
LR_START = 5e-3#5e-3
BATCH_SIZE = 512

def create_model():
    
    reg1 = 9.613e-06
    reg2 = 1e-05
    REG1 = tf.keras.regularizers.l2(reg1)
    REG2 = tf.keras.regularizers.l2(reg2)
    DROP = 0.2

    activation = 'selu'
    inputs = Input(shape =(X.shape[1],))

    x0 = Dense(1024, 
              kernel_regularizer = REG1,
              activation = activation,
             )(inputs)
    

    x0 = Dropout(DROP)(x0)
    
    
    
    x1 = Dense(1024, 
               kernel_regularizer = REG1,
               activation = activation,
             )(x0)

    x1 = Dropout(DROP)(x1)
    
    
    
    x2 = Dense(1024, 
               kernel_regularizer = REG1,
               activation = activation,
             )(x1+x0) 
    

    x2 = Dropout(DROP)(x2)

    
    x3 = Dense(1024,
               kernel_regularizer = REG1,
               activation = activation,
             )(x2+x1)
    

    x3 = Dropout(DROP)(x3)

    x = Concatenate()([
                x0, 
                x1, 
                x2, 
                x3
                ])
    
    x = Dense(Y.shape[1], 
                kernel_regularizer = REG2,
                activation='linear',
                )(x)
    
    x_out = Dense(Y.shape[1], 
                kernel_regularizer = REG2,
                activation=activation,
                )(inputs)
    
    
    x = x + x_out
    
#     mean = Dense(1, 
#                 kernel_regularizer = REG2,
#                 activation='linear',
#                 )(inputs)
        
#     var = Dense(1, 
#                 kernel_regularizer = REG2,
#                 activation='relu',
#                 )(inputs)
    
    
#     x = (x + x_out-mean)/(var+1e-5)

        
    model = Model(inputs, x)
    

    return model

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

EPOCHS = 1100
N_SPLITS = 3

for seed_set in range(1,11):
    print('We start working on seed,', seed_set)
    pred_train = np.zeros((Y.shape[0],Y.shape[1]))

    # np.random.seed(1)
    # tf.random.set_seed(1)
    seed_tensorflow(seed_set)
    score_list = []
    kf = GroupKFold(n_splits=N_SPLITS)
    score_list = []

    for fold, (idx_tr, idx_va) in enumerate(kf.split(X, groups=meta.donor)):
        start_time = datetime.datetime.now()
        model = None
        gc.collect()

        X_tr = X[idx_tr]
        y_tr = Y[idx_tr]
        X_va = X[idx_va]
        y_va = Y[idx_va]

        lr = ReduceLROnPlateau(
                        monitor = "val_loss",
                        factor = 0.9, 
                        patience = 4, 
                        verbose = VERBOSE)

        es = EarlyStopping(
                        monitor = "val_loss",
                        patience = 100, 
                        verbose = VERBOSE,
                        mode = "min", 
                        restore_best_weights = True)

        model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
                        filepath = './citeseq',
                        save_weights_only = True,
                        monitor = 'val_loss',
                        mode = 'min',
                        save_best_only = True)

        callbacks = [   lr, 
                        es, 
                        model_checkpoint_callback
                        ]

        model = create_model()

        model.compile(
                    optimizer = tfa.optimizers.AdaBelief(LR_START),
                    metrics = [negative_correlation_loss],
                    loss = negative_correlation_loss
                     )
        # Training
        model.fit(
                    X_tr,
                    y_tr, 
                    validation_data=(
                                    X_va,
                                    y_va), 
                    epochs = EPOCHS,
                    verbose = VERBOSE,
                    batch_size = BATCH_SIZE,
                    shuffle = True,
                    callbacks = callbacks)

        del X_tr, y_tr 
        gc.collect()

        model.load_weights('./citeseq')
        model.save(f"./submissions/model_{fold}")
        print('model saved')

        #  Model validation
        y_va_pred = model.predict(X_va)
        corrscore = correlation_score(y_va, y_va_pred)
        pred_train[idx_va] = y_va_pred

        print(f"Fold {fold}, correlation =  {corrscore:.5f}")
        del X_va, y_va, y_va_pred
        gc.collect()
        score_list.append(corrscore)

    # Show overall score

    print(f"{Fore.GREEN}{Style.BRIGHT}Mean corr = {np.array(score_list).mean():.5f}{Style.RESET_ALL}")
    score_total = correlation_score(Y, pred_train)
    print(f"{Fore.BLUE}{Style.BRIGHT}Oof corr   = {score_total:.5f}{Style.RESET_ALL}")
    
    Xt = np.hstack((Xt[:,:feature_number_pca],X0t))
    Xt.shape
    
    test_pred = np.zeros((len(Xt), 140), dtype=np.float32)
    for fold in range(N_SPLITS):
        print(f"Predicting with fold {fold}")
        model = load_model(f"./submissions/model_{fold}",
                           custom_objects={'negative_correlation_loss': negative_correlation_loss})
        test_pred += model.predict(Xt)

    print(len(test_pred))
    # Copy the targets for the data leak but useless since the change in the public LB...
    test_pred[:7476] = Y[:7476]
    
#     test_pred = std(test_pred)
    
    submission = pd.read_csv("./submission_ensemble_standard.csv",index_col='row_id', squeeze=True)
    submission.iloc[:len(test_pred.ravel())] = test_pred.ravel()
    assert not submission.isna().any()
    
    save_path = "./ensemblingwork/" + "submission_seed" + str(seed_set) + ".csv"
    submission.to_csv(save_path)
    display(submission)
# Out:
# We start working on seed, 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:61
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
corr_list = [0.89437, 0.89435, 0.89413, 0.89442, 0.89420, 0.89457, 0.89439, 0.89469, 0.89429, 0.89418]

# %%
submission = pd.read_csv("./ensemblingwork/" + "submission_seed" + str(1) + ".csv", index_col=0)
for seed_set in range(2,21):
    save_path = "./ensemblingwork/" + "submission_seed" + str(seed_set) + ".csv"
    submission_save = pd.read_csv(save_path, index_col=0)
    submission += submission_save
submission = submission/20

# %%
submssion_sample = pd.read_csv("evaluation_ids.csv")

# %%
submssion_sample
# Out:
#             row_id       cell_id          gene_id
# 0                0  c2150f55becb             CD86
# 1                1  c2150f55becb            CD274
# 2                2  c2150f55becb            CD270
# 3                3  c2150f55becb            CD155
# 4                4  c2150f55becb            CD112
# ...            ...           ...              ...
# 65744175  65744175  2c53aa67933d  ENSG00000134419
# 65744176  65744176  2c53aa67933d  ENSG00000186862
# 65744177  65744177  2c53aa67933d  ENSG00000170959
# 65744178  65744178  2c53aa67933d  ENSG00000107874
# 65744179  65744179  2c53aa67933d  ENSG00000166012
#
# [65744180 rows x 3 columns]

# %%
# submission = pd.read_csv("./ensemblingwork/" + "submission_seed" + str(8) + ".csv", index_col=0)

# %%
submission
# Out:
#             target
# row_id
# 0         0.094605
# 1        -0.162362
# 2        -0.405332
# 3        -0.302582
# 4         1.114355
# ...            ...
# 65744175  4.425791
# 65744176 -0.604866
# 65744177 -0.597459
# 65744178  0.237816
# 65744179  3.961616
#
# [65744180 rows x 1 columns]

# %%
submission["cell_id"] = submssion_sample["cell_id"]

# %%
submission
# Out:
#             target       cell_id
# row_id
# 0         0.094605  c2150f55becb
# 1        -0.162362  c2150f55becb
# 2        -0.405332  c2150f55becb
# 3        -0.302582  c2150f55becb
# 4         1.114355  c2150f55becb
# ...            ...           ...
# 65744175  4.425791  2c53aa67933d
# 65744176 -0.604866  2c53aa67933d
# 65744177 -0.597459  2c53aa67933d
# 65744178  0.237816  2c53aa67933d
# 65744179  3.961616  2c53aa67933d
#
# [65744180 rows x 2 columns]

# %%
# Standardize submission per cell_id
loop_list          = submission.groupby('cell_id', sort=False)
vals               = []

for idx, g in tqdm(loop_list, desc=f'Standardizing', miniters=1000):
    vals.append(std(g.target).values)

to_save_norm = np.concatenate(vals)
# Out:
# Standardizing:   0%|          | 0/65443 [00:00<?, ?it/s]

# %%
to_save_norm
# Out:
# array([ 0.09460448, -0.16236246, -0.40533193, ..., -0.59745899,
#         0.23781598,  3.9616161 ])

# %%
submission['target'] = to_save_norm.copy()

# %%
del submission['cell_id']

# %%
submission
# Out:
#             target
# row_id
# 0         0.094604
# 1        -0.162362
# 2        -0.405332
# 3        -0.302582
# 4         1.114355
# ...            ...
# 65744175  4.425791
# 65744176 -0.604866
# 65744177 -0.597459
# 65744178  0.237816
# 65744179  3.961616
#
# [65744180 rows x 1 columns]

# %%
submission_bestmulti = pd.read_csv("/ysm-gpfs/pi/zhao/tl688/openproblems/submission_onebestcite.csv", index_col=0)

# %%
submission.iloc[6812820:] = submission_bestmulti[6812820:]

# %%
submission.to_csv("submission_modify_combine.csv")

# %%
submission
# Out:
#             target
# row_id
# 0         0.094604
# 1        -0.162362
# 2        -0.405332
# 3        -0.302582
# 4         1.114355
# ...            ...
# 65744175  6.156170
# 65744176 -0.852548
# 65744177 -0.844325
# 65744178  0.349796
# 65744179  5.507162
#
# [65744180 rows x 1 columns]

# %%
submission_comb = pd.read_csv("./ensemblingwork/" + "submission_seed" + str(8) + ".csv", index_col=0)

# %%
submission = pd.read_csv("/ysm-gpfs/pi/zhao/tl688/openproblems/submission_ensemble_standard.csv", index_col=0)

# %%
submission_comb["cell_id"] = submssion_sample["cell_id"]

# %%
# Standardize submission per cell_id
loop_list          = submission_comb.groupby('cell_id', sort=False)
vals               = []

for idx, g in tqdm(loop_list, desc=f'Standardizing', miniters=1000):
    vals.append(std(g.target).values)

to_save_norm = np.concatenate(vals)
# Out:
# Standardizing:   0%|          | 0/65443 [00:00<?, ?it/s]

# %%
submission_comb['target'] = to_save_norm

# %%
submission.iloc[0:6812820] = submission_comb[0:6812820]

# %%
submission.to_csv("/ysm-gpfs/pi/zhao/tl688/openproblems/submission_modify_8.csv")

# %% [markdown]
# # Change input size

# %%
# constant_cols = list(X.columns[(X == 0).all(axis=0).values]) + list(X_test.columns[(X_test == 0).all(axis=0).values])
# X = pd.read_csv("/gpfs/ysm/home/tl688/scrnahpc/tl688/openproblems/scGNN/outputdir/train_protein_recon.csv",index_col=0).T.drop(columns = constant_cols)
cell_index = X.index
meta = metadata_df.reindex(cell_index)
X0 = X[important_cols].values

del X
gc.collect()


# Read test and convert to sparse matrix
# Xt = pd.read_hdf(FP_CITE_TEST_INPUTS)
Xt = pd.read_hdf(FP_CITE_TEST_INPUTS).drop(columns = constant_cols)
cell_index_test = Xt.index
meta_test = metadata_df.reindex(cell_index_test)
X0t = Xt[important_cols].values

del Xt
gc.collect()

st = StandardScaler()
X0 = st.fit_transform(X0)
X0t = st.transform(X0t)

print(f'X0 shape {X0.shape} X0t shape {X0t.shape}')
# Out:
# X0 shape (70988, 84) X0t shape (48663, 84)

# %%
with open('./input/targets-multiome-sparse-scaled/train_Citeseq_truncated_512.pkl','rb') as f: X = pickle.load(f)
with open('./input/targets-multiome-sparse-scaled/test_Citeseq_truncated_512.pkl','rb') as f: Xt = pickle.load(f)

X.shape, Xt.shape
# Out:
# ((70988, 512), (48663, 512))

# %%
Y = pd.read_hdf(FP_CITE_TRAIN_TARGETS)
Y = Y.values
Y -= Y.mean(axis=1).reshape(-1, 1)
Y /= Y.std(axis=1).reshape(-1, 1)
Y.shape
# Out:
# (70988, 140)

# %%
feature_number_pca = 75

# %%
X = np.hstack((X[:,:feature_number_pca],X0))
X.shape
# Out:
# (70988, 159)

# %%
meta
# Out:
#               day  donor cell_type technology
# cell_id
# 45006fe3e4c8    2  32606       HSC    citeseq
# d02759a80ba2    2  32606       HSC    citeseq
# c016c6b0efa5    2  32606      EryP    citeseq
# ba7f733a4f75    2  32606      NeuP    citeseq
# fbcf2443ffb2    2  32606      EryP    citeseq
# ...           ...    ...       ...        ...
# 650ee456f0f3    4  31800       HSC    citeseq
# cc506e7707f5    4  31800      EryP    citeseq
# a91f1b55a520    4  31800      EryP    citeseq
# 3a9882c98205    4  31800      MasP    citeseq
# c91b6b2ccd3d    4  31800      EryP    citeseq
#
# [70988 rows x 4 columns]

# %%
LR_START = 5e-3#5e-3
BATCH_SIZE = 512

def create_model():
    
    reg1 = 9.613e-06
    reg2 = 1e-05
    REG1 = tf.keras.regularizers.l2(reg1)
    REG2 = tf.keras.regularizers.l2(reg2)
    DROP = 0.2

    activation = 'selu'
    inputs = Input(shape =(X.shape[1],))

    x0 = Dense(1024, 
              kernel_regularizer = REG1,
              activation = activation,
             )(inputs)
    

    x0 = Dropout(DROP)(x0)
    
    
    
    x1 = Dense(1024, 
               kernel_regularizer = REG1,
               activation = activation,
             )(x0)

    x1 = Dropout(DROP)(x1)
    
    
    
    x2 = Dense(1024, 
               kernel_regularizer = REG1,
               activation = activation,
             )(x1+x0) 
    

    x2 = Dropout(DROP)(x2)

    
    x3 = Dense(1024,
               kernel_regularizer = REG1,
               activation = activation,
             )(x2+x1)
    

    x3 = Dropout(DROP)(x3)

    x = Concatenate()([
                x0, 
                x1, 
                x2, 
                x3
                ])
    
    x = Dense(Y.shape[1], 
                kernel_regularizer = REG2,
                activation='linear',
                )(x)
    
    x_out = Dense(Y.shape[1], 
                kernel_regularizer = REG2,
                activation=activation,
                )(inputs)
    
    
    x = x + x_out
    
#     mean = Dense(1, 
#                 kernel_regularizer = REG2,
#                 activation='linear',
#                 )(inputs)
        
#     var = Dense(1, 
#                 kernel_regularizer = REG2,
#                 activation='relu',
#                 )(inputs)
    
    
#     x = (x + x_out-mean)/(var+1e-5)

        
    model = Model(inputs, x)
    

    return model

# %%
def frobenius_norm(m):
    """This function is to calculate the frobenius norm of the matrix of all
    layer's weight.

    Args:
        m: is a list of weights param for each layers.
    """
    total_reduce_sum = 0
    for i in range(len(m)):
        total_reduce_sum = total_reduce_sum + tf.math.reduce_sum(m[i]**2)
    norm = total_reduce_sum**0.5
    return norm

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

EPOCHS = 1100
N_SPLITS = 3

feature_number_pca_list = [80]
for feature_number_pca in feature_number_pca_list:
    
    with open('./input/targets-multiome-sparse-scaled/train_Citeseq_truncated_512.pkl','rb') as f: X = pickle.load(f)
    with open('./input/targets-multiome-sparse-scaled/test_Citeseq_truncated_512.pkl','rb') as f: Xt = pickle.load(f)

    X = np.hstack((X[:,:feature_number_pca],X0))
    

    print('We start working on feature,', feature_number_pca)
    pred_train = np.zeros((Y.shape[0],Y.shape[1]))

    # np.random.seed(1)
    # tf.random.set_seed(1)
    seed_tensorflow(1)
    score_list = []
    kf = GroupKFold(n_splits=N_SPLITS)
    score_list = []

    for fold, (idx_tr, idx_va) in enumerate(kf.split(X, groups=meta.donor)):
        start_time = datetime.datetime.now()
        model = None
        gc.collect()

        X_tr = X[idx_tr]
        y_tr = Y[idx_tr]
        X_va = X[idx_va]
        y_va = Y[idx_va]

        lr = ReduceLROnPlateau(
                        monitor = "val_loss",
                        factor = 0.9, 
                        patience = 4, 
                        verbose = VERBOSE)

        es = EarlyStopping(
                        monitor = "val_loss",
                        patience = 200, 
                        verbose = VERBOSE,
                        mode = "min", 
                        restore_best_weights = True)

        model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
                        filepath = './citeseq',
                        save_weights_only = True,
                        monitor = 'val_loss',
                        mode = 'min',
                        save_best_only = True)

        callbacks = [   lr, 
                        es, 
                        model_checkpoint_callback
                        ]

        model = create_model()

        model.compile(
                    optimizer = tfa.optimizers.AdaBelief(LR_START),
                    metrics = [negative_correlation_loss],
                    loss = negative_correlation_loss
                     )
        # Training
        model.fit(
                    X_tr,
                    y_tr, 
                    validation_data=(
                                    X_va,
                                    y_va), 
                    epochs = EPOCHS,
                    verbose = VERBOSE,
                    batch_size = BATCH_SIZE,
                    shuffle = True,
                    callbacks = callbacks)

        del X_tr, y_tr 
        gc.collect()

        model.load_weights('./citeseq')
        model.save(f"./submissions/model_{fold}")
        print('model saved')

        #  Model validation
        y_va_pred = model.predict(X_va)
        corrscore = correlation_score(y_va, y_va_pred)
        pred_train[idx_va] = y_va_pred

        print(f"Fold {fold}, correlation =  {corrscore:.5f}")
        del X_va, y_va, y_va_pred
        gc.collect()
        score_list.append(corrscore)

    # Show overall score

    print(f"{Fore.GREEN}{Style.BRIGHT}Mean corr = {np.array(score_list).mean():.5f}{Style.RESET_ALL}")
    score_total = correlation_score(Y, pred_train)
    print(f"{Fore.BLUE}{Style.BRIGHT}Oof corr   = {score_total:.5f}{Style.RESET_ALL}")
    
    Xt = np.hstack((Xt[:,:feature_number_pca],X0t))
    Xt.shape
    
    test_pred = np.zeros((len(Xt), 140), dtype=np.float32)
    for fold in range(N_SPLITS):
        print(f"Predicting with fold {fold}")
        model = load_model(f"./submissions/model_{fold}",
                           custom_objects={'negative_correlation_loss': negative_correlation_loss})
        test_pred += model.predict(Xt)

    print(len(test_pred))
    # Copy the targets for the data leak but useless since the change in the public LB...
    test_pred[:7476] = Y[:7476]
    
#     test_pred = std(test_pred)
    
    submission = pd.read_csv("./submission_ensemble_cite_standardmulti.csv",index_col='row_id', squeeze=True)
    submission.iloc[:len(test_pred.ravel())] = test_pred.ravel()
    assert not submission.isna().any()
    
    save_path = "./ensemblingwork_pca/" + "submission_pca" + str(feature_number_pca) + ".csv"
    submission.to_csv(save_path)
    display(submission)
# Out:
# We start working on feature, 80
# 2022-11-06 17:47:10.230984: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-06 17:47:15.459497: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22291 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1d:00.0, compute capability: 8.6
# 2022-11-06 17:47:29.694298: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# INFO:tensorflow:Assets written to: ./submissions/model_0/assets
# model saved
# 776/776 [==============================] - 1s 1ms/step
# Fold 0, correlation =  0.89265
# INFO:tensorflow:Assets written to: ./submissions/model_1/assets
# model saved
# 750/750 [==============================] - 1s 1ms/step
# Fold 1, correlation =  0.89716
# INFO:tensorflow:Assets written to: ./submissions/model_2/assets
# model saved
# 694/694 [==============================] - 1s 1ms/step
# Fold 2, correlation =  0.89413
# Mean corr = 0.89465
# Oof corr   = 0.89464
# Predicting with fold 0
# 1521/1521 [==============================] - 2s 1ms/step
# Predicting with fold 1
# 1521/1521 [==============================] - 2s 1ms/step
# Predicting with fold 2
# 1521/1521 [==============================] - 2s 1ms/step
# 48663
# row_id
# 0           0.094605
# 1          -0.162362
# 2          -0.405332
# 3          -0.302582
# 4           1.114355
#               ...
# 65744175    4.406590
# 65744176   -0.603898
# 65744177   -0.595424
# 65744178    0.224828
# 65744179    3.913553
# Name: target, Length: 65744180, dtype: float64
# CPU times: user 11min 57s, sys: 30.3 s, total: 12min 28s
# Wall time: 15min 50s

# %%
submission = pd.read_csv("./ensemblingwork_pca/" + "submission_pca" + str(70) + ".csv", index_col=0)
for seed_set in [71,72,73,74,75,76,77,78,79,80]:
    save_path = "./ensemblingwork_pca/" + "submission_pca" + str(seed_set) + ".csv"
    submission_save = pd.read_csv(save_path, index_col=0)
    submission += submission_save
submission = submission/10

# %%
submission
# Out:
#             target
# row_id
# 0         0.104065
# 1        -0.178599
# 2        -0.445865
# 3        -0.332840
# 4         1.225791
# ...            ...
# 65744175  4.847249
# 65744176 -0.664288
# 65744177 -0.654967
# 65744178  0.247310
# 65744179  4.304908
#
# [65744180 rows x 1 columns]

# %%
submssion_sample = pd.read_csv("evaluation_ids.csv")

# %%
submssion_sample
# Out:
#             row_id       cell_id          gene_id
# 0                0  c2150f55becb             CD86
# 1                1  c2150f55becb            CD274
# 2                2  c2150f55becb            CD270
# 3                3  c2150f55becb            CD155
# 4                4  c2150f55becb            CD112
# ...            ...           ...              ...
# 65744175  65744175  2c53aa67933d  ENSG00000134419
# 65744176  65744176  2c53aa67933d  ENSG00000186862
# 65744177  65744177  2c53aa67933d  ENSG00000170959
# 65744178  65744178  2c53aa67933d  ENSG00000107874
# 65744179  65744179  2c53aa67933d  ENSG00000166012
#
# [65744180 rows x 3 columns]

# %%
submission["cell_id"] = submssion_sample ["cell_id"]

# %%
submission
# Out:
#             target       cell_id
# row_id
# 0         0.104065  c2150f55becb
# 1        -0.178599  c2150f55becb
# 2        -0.445865  c2150f55becb
# 3        -0.332840  c2150f55becb
# 4         1.225791  c2150f55becb
# ...            ...           ...
# 65744175  4.847249  2c53aa67933d
# 65744176 -0.664288  2c53aa67933d
# 65744177 -0.654967  2c53aa67933d
# 65744178  0.247310  2c53aa67933d
# 65744179  4.304908  2c53aa67933d
#
# [65744180 rows x 2 columns]

# %%
# Standardize submission per cell_id
loop_list          = submission.groupby('cell_id', sort=False)
vals               = []

for idx, g in tqdm(loop_list, desc=f'Standardizing', miniters=1000):
    vals.append(std(g.target).values)

to_save_norm = np.concatenate(vals)
# Out:
# Standardizing:   0%|          | 0/65443 [00:00<?, ?it/s]

# %%
to_save_norm
# Out:
# array([ 0.09460448, -0.16236246, -0.40533193, ..., -0.59542426,
#         0.2248275 ,  3.91355303])

# %%
submission['target'] = to_save_norm

# %%
del submission['cell_id']

# %%
submission
# Out:
#             target
# row_id
# 0         0.094604
# 1        -0.162362
# 2        -0.405332
# 3        -0.302582
# 4         1.114355
# ...            ...
# 65744175  4.406590
# 65744176 -0.603898
# 65744177 -0.595424
# 65744178  0.224828
# 65744179  3.913553
#
# [65744180 rows x 1 columns]

# %%
submission.to_csv("submission_10_pca_combine.csv")

# %%
submission
# Out:
#             target
# row_id
# 0         0.094604
# 1        -0.162362
# 2        -0.405332
# 3        -0.302582
# 4         1.114355
# ...            ...
# 65744175  4.406590
# 65744176 -0.603898
# 65744177 -0.595424
# 65744178  0.224828
# 65744179  3.913553
#
# [65744180 rows x 1 columns]

# %%
submission_correct = pd.read_csv("/ysm-gpfs/pi/zhao/tl688/openproblems/submission_10_combine.csv", index_col=0)
submission_wrong = pd.read_csv("/ysm-gpfs/pi/zhao/tl688/openproblems/submission_wrongsubmission.csv", index_col=0)

# %%
submission_correct
# Out:
#             target
# row_id
# 0         0.094604
# 1        -0.162362
# 2        -0.405332
# 3        -0.302582
# 4         1.114355
# ...            ...
# 65744175  6.156170
# 65744176 -0.852548
# 65744177 -0.844325
# 65744178  0.349796
# 65744179  5.507162
#
# [65744180 rows x 1 columns]

# %%
submission_ty = pd.read_csv("tianyu_standard_cite.csv", index_col=0)

# %%
submission_sma = pd.read_csv("sma_standard_cite.csv", index_col=0)

# %%
submission_ty
# Out:
#             target
# row_id
# 0         0.094604
# 1        -0.162362
# 2        -0.405332
# 3        -0.302582
# 4         1.114355
# ...            ...
# 65744175  6.156170
# 65744176 -0.852548
# 65744177 -0.844325
# 65744178  0.349796
# 65744179  5.507162
#
# [65744180 rows x 1 columns]

# %%
submission_sma.iloc[0:6812820] = submission_ty.iloc[0:6812820]

# %%
submission_sma.to_csv("submission_testourcite.csv")

# %%
data_path = "/ysm-gpfs/pi/zhao/tl688/openproblems/input/multimodal-single-cell-as-sparse-matrix/test_cite_inputs_values.sparse.npz"
train = scipy.sparse.load_npz(data_path)

# %%
import sklearn

# %%
model = sklearn.decomposition.PCA(n_components=512)

# %%
train_out = model.fit_transform(train.todense())
# Out:
# /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/sklearn/utils/validation.py:727: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(

# %%
train_out.shape
# Out:
# (48663, 512)

# %%
# u, s, vT = scipy.sparse.linalg.svds(train, k=128)

# %%
# train_out = u.dot(np.diag(s))

# %%
# train_out.shape
# Out:
# (70988, 128)

# %%
pkl_filename = "test_cite_512.pkl"

# %%
with open(pkl_filename, 'wb') as file:
    pickle.dump(train_out, file)

# %%
data_path = "/ysm-gpfs/pi/zhao/tl688/openproblems/input/multimodal-single-cell-as-sparse-matrix/train_cite_inputs_values.sparse.npz"
train = scipy.sparse.load_npz(data_path)

# %%
u, s, vT = scipy.sparse.linalg.svds(train, k=512)

# %%
train_out = u.dot(np.diag(s))

# %%
train_out[:,::-1]
# Out:
# array([[-2.3822762e+02,  3.1855104e+01,  2.3049294e+01, ...,
#         -1.3715878e+00, -2.8723223e+00, -1.4102858e+00],
#        [-2.3365659e+02,  4.0229019e+01,  1.9437603e+01, ...,
#          3.7163601e+00,  4.1906461e-01, -1.3358747e+00],
#        [-2.5014233e+02, -4.6703153e+00,  9.4395075e+00, ...,
#         -3.6248217e+00,  2.4677904e+00,  3.7641099e-01],
#        ...,
#        [-2.6739429e+02, -1.4522221e+01,  8.5594721e+00, ...,
#          2.5515324e-01,  2.7128370e+00, -1.5232078e+00],
#        [-2.7380966e+02, -2.3930012e+01, -3.1388956e+01, ...,
#         -2.1867669e+00, -3.8604670e+00,  5.6192124e-01],
#        [-2.3833578e+02,  1.1786343e+01,  1.1732360e+01, ...,
#         -3.7178817e+00,  8.2002485e-01, -1.9139581e+00]], dtype=float32)

# %%
np.std(train_out[:,::-1], axis=0)
# Out:
# array([30.375257 , 26.91837  , 21.573349 , 18.739716 , 16.615198 ,
#        13.227979 , 11.472698 , 10.428644 ,  9.999443 ,  8.605583 ,
#         8.355967 ,  7.7108827,  7.2348576,  6.828668 ,  6.5244465,
#         6.126846 ,  5.8108683,  5.406348 ,  4.9885864,  4.825242 ,
#         4.7263103,  4.401399 ,  4.3118143,  4.1695824,  4.051741 ,
#         4.035068 ,  3.9138656,  3.8137624,  3.676365 ,  3.5272353,
#         3.5001812,  3.381876 ,  3.3740146,  3.2949069,  3.2515957,
#         3.1779337,  3.161723 ,  3.113488 ,  3.0597708,  3.027244 ,
#         2.301817 ,  2.3017392,  2.3010812,  2.3009892,  2.3007777,
#         2.3005013,  2.300212 ,  2.3001156,  2.3000216,  2.2994683,
#         2.2993557,  2.2991786,  2.2988381,  2.2986786,  2.2983747,
#         2.2979348,  2.2977788,  2.2974465,  2.297309 ,  2.2972214,
#         2.296949 ,  2.2966223,  2.2962353,  2.2960136,  2.2959425,
#         2.2955835,  2.2951024,  2.2949898,  2.2946599,  2.2944722,
#         2.2943382,  2.2941093,  2.2936497,  2.2935824,  2.293355 ,
#         2.2929993,  2.2926955,  2.2925227,  2.2922683,  2.292066 ,
#         2.2918358,  2.291657 ,  2.2915967,  2.2912755,  2.290965 ,
#         2.2906399,  2.2903786,  2.2903454,  2.289807 ,  2.2895253,
#         2.289465 ,  2.2891166,  2.2886167,  2.2884948,  2.2882104,
#         2.28802  ,  2.2878323,  2.2876062,  2.2872596,  2.287197 ,
#         2.2867894,  2.2864187,  2.2860606,  2.2857347,  2.2853994,
#         2.2850995,  2.2850049,  2.2849517,  2.2846265,  2.284377 ,
#         2.2843418,  2.2838101,  2.2837765,  2.2836564,  2.2832634,
#         2.2831786,  2.2827172], dtype=float32)

# %%
pkl_filename = "train_cite_512.pkl"

# %%
with open(pkl_filename, 'wb') as file:
    pickle.dump(train_out[:,::-1], file)

# %%
# Out:
# (48663, 128)

# %%
data_path = "/ysm-gpfs/pi/zhao/tl688/openproblems/input/multimodal-single-cell-as-sparse-matrix/test_cite_inputs_values.sparse.npz"
test = scipy.sparse.load_npz(data_path)

# %%
test_result = test @ np.transpose(vT)

# %%
pkl_filename = "test_cite_512.pkl"

# %%
with open(pkl_filename, 'wb') as file:
    pickle.dump(test_result[:,::-1], file)

# %%
np.std(test_result[:,::-1], axis=0)
# Out:
# array([32.68644  , 25.180162 , 23.764141 , 21.73299  , 17.029184 ,
#        19.265198 , 14.848934 , 11.346035 ,  9.450535 , 12.354806 ,
#         9.460149 ,  8.3627205, 10.149748 ,  6.7108583,  5.003267 ,
#         6.4000144,  6.4030294,  5.3740826,  9.131994 ,  5.498298 ,
#         5.8245015,  4.7920375,  4.709583 ,  6.8064227,  5.04601  ,
#         4.0840592,  4.5082254,  3.9793437,  3.934653 ,  4.6338983,
#         4.4533544,  3.276511 ,  3.447385 ,  3.8420873,  3.9942055,
#         3.5782282,  4.075223 ,  3.5485573,  3.435077 ,  2.883861 ,
#         3.4538996,  2.8564909,  2.9337335,  3.0643988,  3.0189426,
#         3.3068073,  2.8263333,  2.835357 ,  2.8102505,  2.92223  ,
#         2.721527 ,  2.681071 ,  2.64365  ,  2.4874492,  2.5603101,
#         2.5583553,  2.7103102,  2.5181084,  2.416626 ,  2.3963344,
#         2.3147671,  2.4001465,  2.4201431,  2.3519557,  2.3321655,
#         2.3296359,  2.3533387,  2.285748 ,  2.2059114,  2.3186588,
#         2.238971 ,  2.1972866,  2.224758 ,  2.2879932,  2.1973608,
#         2.2174745,  2.1916008,  2.1425452,  2.1289024,  2.104885 ,
#         2.0527818,  2.170075 ,  2.1399972,  2.1103175,  2.060116 ,
#         1.9168805,  1.9055905,  1.9132301,  1.903594 ,  1.9116294,
#         1.9236834,  1.9179463,  1.9054116,  1.9006292,  1.9064336,
#         1.9187837,  1.9300734,  1.9051156,  1.9165236,  1.9195591,
#         1.9348328,  1.9139359,  1.9070514,  1.8937443,  1.9094383,
#         1.9262148,  1.9010675], dtype=float32)

# %% [markdown]
# # Single prediction

# %%
import os, gc, pickle, datetime, scipy.sparse,random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from colorama import Fore, Back, Style

import sklearn 
from sklearn.model_selection import GroupKFold,train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD,PCA
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
from cycler import cycler
from IPython.display import display

import scipy.sparse
from tqdm.notebook import tqdm

DATA_DIR = "./"
FP_CELL_METADATA = os.path.join(DATA_DIR,"metadata.csv")

FP_CITE_TRAIN_INPUTS = os.path.join(DATA_DIR,"train_cite_inputs.h5")
FP_CITE_TRAIN_TARGETS = os.path.join(DATA_DIR,"train_cite_targets.h5")
FP_CITE_TEST_INPUTS = os.path.join(DATA_DIR,"test_cite_inputs.h5")

FP_SUBMISSION = os.path.join(DATA_DIR,"sample_submission.csv")
FP_EVALUATION_IDS = os.path.join(DATA_DIR,"evaluation_ids.csv")

VERBOSE = 0

# %%
import math

import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow_addons as tfa
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, LearningRateScheduler, EarlyStopping
from tensorflow.keras.layers import Dense, Input, Concatenate, Dropout, BatchNormalization, AlphaDropout
import keras_tuner
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2022-11-11 00:14:21.236452: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available:  0
# 2022-11-11 00:14:25.863028: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-11-11 00:14:25.863085: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-11 00:14:25.863113: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c14n12.farnam.hpc.yale.internal): /proc/driver/nvidia/version does not exist

# %%
# Standardize
def std(x):
    empty_list = []
    for item in x:
        empty_list.append((item - np.mean(item)) / np.std(item))
    return np.array(empty_list)

# %%
import anndata as ad

# %%
def seed_tensorflow(seed=1):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

# %%
# constant_cols = list(X.columns[(X == 0).all(axis=0).values]) + list(X_test.columns[(X_test == 0).all(axis=0).values])
constant_cols = ['ENSG00000003137_CYP26B1', 'ENSG00000004848_ARX', 'ENSG00000006606_CCL26', 'ENSG00000010379_SLC6A13', 'ENSG00000010932_FMO1', 'ENSG00000017427_IGF1', 'ENSG00000022355_GABRA1', 'ENSG00000041982_TNC', 'ENSG00000060709_RIMBP2', 'ENSG00000064886_CHI3L2', 'ENSG00000065717_TLE2', 'ENSG00000067798_NAV3', 'ENSG00000069535_MAOB', 'ENSG00000073598_FNDC8', 'ENSG00000074219_TEAD2', 'ENSG00000074964_ARHGEF10L', 'ENSG00000077264_PAK3', 'ENSG00000078053_AMPH', 'ENSG00000082684_SEMA5B', 'ENSG00000083857_FAT1', 'ENSG00000084628_NKAIN1', 'ENSG00000084734_GCKR', 'ENSG00000086967_MYBPC2', 'ENSG00000087258_GNAO1', 'ENSG00000089505_CMTM1', 'ENSG00000091129_NRCAM', 'ENSG00000091986_CCDC80', 'ENSG00000092377_TBL1
 'ENSG00000108107_RPL28',
 'ENSG00000143226_FCGR2A',
 'ENSG00000133112_TPT1',
 'ENSG00000166091_CMTM5',
 'ENSG00000026025_VIM',
 'ENSG00000205542_TMSB4X',
 'ENSG00000109099_PMP22',
 'ENSG00000145425_RPS3A',
 'ENSG00000172247_C1QTNF4',
 'ENSG00000072274_TFRC',
 'ENSG00000234745_HLA-B',
 'ENSG00000075340_ADD2',
 'ENSG00000119865_CNRIP1',
 'ENSG00000198938_MT-CO3',
 'ENSG00000135046_ANXA1',
 'ENSG00000235169_SMIM1',
 'ENSG00000101200_AVP',
 'ENSG00000167996_FTH1',
 'ENSG00000163565_IFI16',
 'ENSG00000117450_PRDX1',
 'ENSG00000124570_SERPINB6',
 'ENSG00000112077_RHAG',
 'ENSG00000051523_CYBA',
 'ENSG00000107130_NCS1',
 'ENSG00000055118_KCNH2',
 'ENSG00000029534_ANK1',
 'ENSG00000169567_HINT1',
 'ENSG00000142089_IFITM3',
 'ENSG00000139278_GLIPR1',
 'ENSG00000142227_EMP3',
 'ENSG00000076662_ICAM3',
 'ENSG00000143627_PKLR',
 'ENSG00000130755_GMFG',
 'ENSG00000160593_JAML',
 'ENSG00000095932_SMIM24',
 'ENSG00000197956_S100A6',
 'ENSG00000171476_HOPX',
 'ENSG00000116675_DNAJC6',
 'ENSG00000100448_CTSG',
 'ENSG00000100368_CSF2RB',
 'ENSG00000047648_ARHGAP6',
 'ENSG00000198918_RPL39',
 'ENSG00000196154_S100A4',
 'ENSG00000233968_AL157895.1',
 'ENSG00000137642_SORL1',
 'ENSG00000133816_MICAL2',
 'ENSG00000130208_APOC1',
 'ENSG00000105610_KLF1']
print('important columns ',len(important_cols))
# Out:
# Constant cols: 1194
# important columns  84

# %%
def correlation_score(y_true, y_pred):
    if type(y_true) == pd.DataFrame: y_true = y_true.values
    if type(y_pred) == pd.DataFrame: y_pred = y_pred.values
    corrsum = 0
    for i in range(len(y_true)):
        corrsum += np.corrcoef(y_true[i], y_pred[i])[1, 0]
    return corrsum / len(y_true)

def negative_correlation_loss(y_true, y_pred):
    my = K.mean(tf.convert_to_tensor(y_pred), axis=1)
    my = tf.tile(tf.expand_dims(my, axis=1), (1, y_true.shape[1]))
    ym = y_pred - my
    r_num = K.sum(tf.multiply(y_true, ym), axis=1)
    r_den = tf.sqrt(K.sum(K.square(ym), axis=1) * float(y_true.shape[-1]))
    r = tf.reduce_mean(r_num / r_den)
    return - r

def correlation_score_new(y_true, y_pred):
    if type(y_true) == pd.DataFrame: y_true = y_true.values
    if type(y_pred) == pd.DataFrame: y_pred = y_pred.values
    return np.corrcoef(y_true, y_pred)

# %%
correlation_score_new(np.array([1,0,1]), np.array([2,1,2]))
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
np.array([1,1,1]).T
# Out:
# array([1, 1, 1])

# %%
metadata_df = pd.read_csv(FP_CELL_METADATA, index_col = 'cell_id')
metadata_df = metadata_df[metadata_df.technology == "citeseq"]

# Read train and convert to sparse matrix
# X = pd.read_hdf(FP_CITE_TRAIN_INPUTS)
X = pd.read_hdf(FP_CITE_TRAIN_INPUTS).drop(columns = constant_cols)
# X = pd.read_csv("/gpfs/ysm/home/tl688/scrnahpc/tl688/openproblems/scGNN/outputdir/train_protein_recon.csv",index_col=0).T.drop(columns = constant_cols)
cell_index = X.index
meta = metadata_df.reindex(cell_index)


# Read test and convert to sparse matrix
# Xt = pd.read_hdf(FP_CITE_TEST_INPUTS)
Xt = pd.read_hdf(FP_CITE_TEST_INPUTS).drop(columns = constant_cols)
cell_index_test = Xt.index
meta_test = metadata_df.reindex(cell_index_test)



# st = StandardScaler()
# X = st.fit_transform(X)
# Xt = st.transform(Xt)

# %%
st = StandardScaler()
X_s = st.fit_transform(X.values)
Xt_s = st.transform(Xt.values)

# %%
X.iloc[:,:] = X_s
Xt.iloc[:,:] = Xt_s

# %%
X
# Out:
# gene_id       ENSG00000121410_A1BG  ENSG00000268895_A1BG-AS1  \
# cell_id
# 45006fe3e4c8              -0.15239                 -0.236089
# d02759a80ba2              -0.15239                 -0.236089
# c016c6b0efa5              -0.15239                 -0.236089
# ba7f733a4f75              -0.15239                 -0.236089
# fbcf2443ffb2              -0.15239                 -0.236089
# ...                            ...                       ...
# 650ee456f0f3              -0.15239                 -0.236089
# cc506e7707f5              -0.15239                 -0.236089
# a91f1b55a520              -0.15239                 -0.236089
# 3a9882c98205              -0.15239                 -0.236089
# c91b6b2ccd3d              -0.15239                 -0.236089
#
# gene_id       ENSG00000175899_A2M  ENSG00000245105_A2M-AS1  \
# cell_id
# 45006fe3e4c8            -0.066677                -0.213677
# d02759a80ba2            -0.066677                -0.213677
# c016c6b0efa5            -0.066677                -0.213677
# ba7f733a4f75            -0.066677                -0.213677
# fbcf2443ffb2            -0.066677                -0.213677
# ...                           ...                      ...
# 650ee456f0f3            -0.066677                -0.213677
# cc506e7707f5            -0.066677                -0.213677
# a91f1b55a520            -0.066677                -0.213677
# 3a9882c98205            -0.066677                -0.213677
# c91b6b2ccd3d            -0.066677                -0.213677
#
# gene_id       ENSG00000128274_A4GALT  ENSG00000094914_AAAS  \
# cell_id
# 45006fe3e4c8               -0.162106             -0.876378
# d02759a80ba2               -0.162106             -0.876378
# c016c6b0efa5                6.292244             -0.876378
# ba7f733a4f75               -0.162106              0.861680
# fbcf2443ffb2               -0.162106             -0.876378
# ...                              ...                   ...
# 650ee456f0f3               -0.162106             -0.876378
# cc506e7707f5               -0.162106              1.137101
# a91f1b55a520               -0.162106             -0.876378
# 3a9882c98205               -0.162106              1.096361
# c91b6b2ccd3d               -0.162106             -0.876378
#
# gene_id       ENSG00000081760_AACS  ENSG00000109576_AADAT  \
# cell_id
# 45006fe3e4c8             -0.827405              -0.285128
# d02759a80ba2             -0.827405              -0.285128
# c016c6b0efa5              1.113428               3.547482
# ba7f733a4f75              0.906359              -0.285128
# fbcf2443ffb2              1.289741              -0.285128
# ...                            ...                    ...
# 650ee456f0f3             -0.827405              -0.285128
# cc506e7707f5              1.526039              -0.285128
# a91f1b55a520              1.441519              -0.285128
# 3a9882c98205             -0.827405              -0.285128
# c91b6b2ccd3d             -0.827405              -0.285128
#
# gene_id       ENSG00000103591_AAGAB  ENSG00000115977_AAK1  ...  \
# cell_id                                                    ...
# 45006fe3e4c8              -0.697792             -1.093317  ...
# d02759a80ba2              -0.697792              0.822107  ...
# c016c6b0efa5              -0.697792             -1.093317  ...
# ba7f733a4f75              -0.697792              1.046975  ...
# fbcf2443ffb2              -0.697792             -1.093317  ...
# ...                             ...                   ...  ...
# 650ee456f0f3              -0.697792             -1.093317  ...
# cc506e7707f5              -0.697792             -1.093317  ...
# a91f1b55a520               1.760215              0.715930  ...
# 3a9882c98205               1.807321              1.670767  ...
# c91b6b2ccd3d              -0.697792             -1.093317  ...
#
# gene_id       ENSG00000153975_ZUP1  ENSG00000086827_ZW10  \
# cell_id
# 45006fe3e4c8             -0.589172             -0.767604
# d02759a80ba2             -0.589172             -0.767604
# c016c6b0efa5             -0.589172             -0.767604
# ba7f733a4f75              1.449651             -0.767604
# fbcf2443ffb2             -0.589172              1.440852
# ...                            ...                   ...
# 650ee456f0f3             -0.589172              1.546469
# cc506e7707f5              1.772733             -0.767604
# a91f1b55a520             -0.589172             -0.767604
# 3a9882c98205             -0.589172             -0.767604
# c91b6b2ccd3d              1.896145             -0.767604
#
# gene_id       ENSG00000174442_ZWILCH  ENSG00000122952_ZWINT  \
# cell_id
# 45006fe3e4c8               -0.865788              -1.641808
# d02759a80ba2               -0.865788               0.305982
# c016c6b0efa5                1.078776               0.542346
# ba7f733a4f75                1.213454               0.778843
# fbcf2443ffb2                1.255428               0.381821
# ...                              ...                    ...
# 650ee456f0f3                1.356873               0.809844
# cc506e7707f5                1.492180               0.277978
# a91f1b55a520               -0.865788               0.526894
# 3a9882c98205                1.451063               0.762318
# c91b6b2ccd3d               -0.865788               0.378289
#
# gene_id       ENSG00000198205_ZXDA  ENSG00000198455_ZXDB  \
# cell_id
# 45006fe3e4c8              -0.12657             -0.237671
# d02759a80ba2              -0.12657             -0.237671
# c016c6b0efa5              -0.12657             -0.237671
# ba7f733a4f75              -0.12657             -0.237671
# fbcf2443ffb2              -0.12657             -0.237671
# ...                            ...                   ...
# 650ee456f0f3              -0.12657             -0.237671
# cc506e7707f5              -0.12657             -0.237671
# a91f1b55a520              -0.12657             -0.237671
# 3a9882c98205              -0.12657             -0.237671
# c91b6b2ccd3d              -0.12657             -0.237671
#
# gene_id       ENSG00000070476_ZXDC  ENSG00000162378_ZYG11B  \
# cell_id
# 45006fe3e4c8             -0.551475               -0.664261
# d02759a80ba2             -0.551475               -0.664261
# c016c6b0efa5             -0.551475                1.459987
# ba7f733a4f75             -0.551475                1.233349
# fbcf2443ffb2              1.616453                1.652962
# ...                            ...                     ...
# 650ee456f0f3             -0.551475               -0.664261
# cc506e7707f5             -0.551475               -0.664261
# a91f1b55a520              1.799451                1.819083
# 3a9882c98205             -0.551475               -0.664261
# c91b6b2ccd3d             -0.551475               -0.664261
#
# gene_id       ENSG00000159840_ZYX  ENSG00000074755_ZZEF1
# cell_id
# 45006fe3e4c8             0.617446              -0.551096
# d02759a80ba2            -1.336204              -0.551096
# c016c6b0efa5             0.501443              -0.551096
# ba7f733a4f75             0.628716              -0.551096
# fbcf2443ffb2             0.344437              -0.551096
# ...                           ...                    ...
# 650ee456f0f3             0.764249               2.158987
# cc506e7707f5             0.565517              -0.551096
# a91f1b55a520            -1.336204              -0.551096
# 3a9882c98205            -1.336204               1.852928
# c91b6b2ccd3d             0.664884               2.030782
#
# [70988 rows x 20856 columns]

# %%
Xt
# Out:
# gene_id       ENSG00000121410_A1BG  ENSG00000268895_A1BG-AS1  \
# cell_id
# c2150f55becb                   0.0                       0.0
# 65b7edf8a4da                   0.0                       0.0
# c1b26cb1057b                   0.0                       0.0
# 917168fa6f83                   0.0                       0.0
# 2b29feeca86d                   0.0                       0.0
# ...                            ...                       ...
# a9b4d99f1f50                   0.0                       0.0
# 0e2c1d0782af                   0.0                       0.0
# a3cbc5aa0ec3                   0.0                       0.0
# 75b350243add                   0.0                       0.0
# ad5a949989b2                   0.0                       0.0
#
# gene_id       ENSG00000175899_A2M  ENSG00000245105_A2M-AS1  \
# cell_id
# c2150f55becb                  0.0                      0.0
# 65b7edf8a4da                  0.0                      0.0
# c1b26cb1057b                  0.0                      0.0
# 917168fa6f83                  0.0                      0.0
# 2b29feeca86d                  0.0                      0.0
# ...                           ...                      ...
# a9b4d99f1f50                  0.0                      0.0
# 0e2c1d0782af                  0.0                      0.0
# a3cbc5aa0ec3                  0.0                      0.0
# 75b350243add                  0.0                      0.0
# ad5a949989b2                  0.0                      0.0
#
# gene_id       ENSG00000128274_A4GALT  ENSG00000094914_AAAS  \
# cell_id
# c2150f55becb                0.000000              0.000000
# 65b7edf8a4da                0.000000              0.000000
# c1b26cb1057b                3.847321              0.000000
# 917168fa6f83                0.000000              3.436846
# 2b29feeca86d                0.000000              0.000000
# ...                              ...                   ...
# a9b4d99f1f50                0.000000              0.000000
# 0e2c1d0782af                0.000000              0.000000
# a3cbc5aa0ec3                0.000000              0.000000
# 75b350243add                0.000000              3.624848
# ad5a949989b2                0.000000              0.000000
#
# gene_id       ENSG00000081760_AACS  ENSG00000109576_AADAT  \
# cell_id
# c2150f55becb              0.000000               0.000000
# 65b7edf8a4da              0.000000               0.000000
# c1b26cb1057b              3.847321               3.847321
# 917168fa6f83              3.436846               0.000000
# 2b29feeca86d              4.196826               0.000000
# ...                            ...                    ...
# a9b4d99f1f50              0.000000               0.000000
# 0e2c1d0782af              0.000000               4.026206
# a3cbc5aa0ec3              0.000000               0.000000
# 75b350243add              3.624848               0.000000
# ad5a949989b2              4.452700               0.000000
#
# gene_id       ENSG00000103591_AAGAB  ENSG00000115977_AAK1  ...  \
# cell_id                                                    ...
# c2150f55becb               0.000000              0.000000  ...
# 65b7edf8a4da               0.000000              4.039545  ...
# c1b26cb1057b               0.000000              0.000000  ...
# 917168fa6f83               0.000000              4.513782  ...
# 2b29feeca86d               0.000000              0.000000  ...
# ...                             ...                   ...  ...
# a9b4d99f1f50               3.719836              0.000000  ...
# 0e2c1d0782af               0.000000              0.000000  ...
# a3cbc5aa0ec3               0.000000              0.000000  ...
# 75b350243add               0.000000              3.624848  ...
# ad5a949989b2               3.377115              0.000000  ...
#
# gene_id       ENSG00000153975_ZUP1  ENSG00000086827_ZW10  \
# cell_id
# c2150f55becb              0.000000              0.000000
# 65b7edf8a4da              0.000000              0.000000
# c1b26cb1057b              0.000000              0.000000
# 917168fa6f83              3.436846              0.000000
# 2b29feeca86d              0.000000              4.196826
# ...                            ...                   ...
# a9b4d99f1f50              0.000000              0.000000
# 0e2c1d0782af              4.026206              0.000000
# a3cbc5aa0ec3              0.000000              0.000000
# 75b350243add              0.000000              0.000000
# ad5a949989b2              3.377115              3.377115
#
# gene_id       ENSG00000174442_ZWILCH  ENSG00000122952_ZWINT  \
# cell_id
# c2150f55becb                0.000000               0.000000
# 65b7edf8a4da                0.000000               4.039545
# c1b26cb1057b                3.847321               4.529743
# 917168fa6f83                4.113780               5.020215
# 2b29feeca86d                4.196826               4.196826
# ...                              ...                    ...
# a9b4d99f1f50                0.000000               3.719836
# 0e2c1d0782af                0.000000               4.026206
# a3cbc5aa0ec3                4.306634               0.000000
# 75b350243add                0.000000               3.624848
# ad5a949989b2                0.000000               4.737466
#
# gene_id       ENSG00000198205_ZXDA  ENSG00000198455_ZXDB  \
# cell_id
# c2150f55becb              0.000000                   0.0
# 65b7edf8a4da              0.000000                   0.0
# c1b26cb1057b              0.000000                   0.0
# 917168fa6f83              0.000000                   0.0
# 2b29feeca86d              0.000000                   0.0
# ...                            ...                   ...
# a9b4d99f1f50              0.000000                   0.0
# 0e2c1d0782af              0.000000                   0.0
# a3cbc5aa0ec3              0.000000                   0.0
# 75b350243add              3.624848                   0.0
# ad5a949989b2              0.000000                   0.0
#
# gene_id       ENSG00000070476_ZXDC  ENSG00000162378_ZYG11B  \
# cell_id
# c2150f55becb               0.00000                0.000000
# 65b7edf8a4da               0.00000                0.000000
# c1b26cb1057b               0.00000                3.847321
# 917168fa6f83               0.00000                3.436846
# 2b29feeca86d               3.51861                4.196826
# ...                            ...                     ...
# a9b4d99f1f50               0.00000                0.000000
# 0e2c1d0782af               0.00000                0.000000
# a3cbc5aa0ec3               0.00000                4.306634
# 75b350243add               0.00000                3.624848
# ad5a949989b2               0.00000                0.000000
#
# gene_id       ENSG00000159840_ZYX  ENSG00000074755_ZZEF1
# cell_id
# c2150f55becb             4.090185               0.000000
# 65b7edf8a4da             0.000000               0.000000
# c1b26cb1057b             3.847321               0.000000
# 917168fa6f83             4.113780               0.000000
# 2b29feeca86d             3.518610               0.000000
# ...                           ...                    ...
# a9b4d99f1f50             3.719836               0.000000
# 0e2c1d0782af             4.710393               0.000000
# a3cbc5aa0ec3             6.933096               4.993019
# 75b350243add             0.000000               0.000000
# ad5a949989b2             0.000000               0.000000
#
# [48663 rows x 20856 columns]

# %%
Y = pd.read_hdf(FP_CITE_TRAIN_TARGETS)
print(Y.columns)
Y = Y.values
Y -= Y.mean(axis=1).reshape(-1, 1)
Y /= Y.std(axis=1).reshape(-1, 1)
Y.shape
# Out:
# Index(['CD86', 'CD274', 'CD270', 'CD155', 'CD112', 'CD47', 'CD48', 'CD40',
#        'CD154', 'CD52',
#        ...
#        'CD94', 'CD162', 'CD85j', 'CD23', 'CD328', 'HLA-E', 'CD82', 'CD101',
#        'CD88', 'CD224'],
#       dtype='object', name='gene_id', length=140)
# (70988, 140)

# %%
LR_START = 5e-4#5e-3
BATCH_SIZE = 512

def create_model():
    
    reg1 = 9.613e-06
    reg2 = 1e-07
    REG1 = tf.keras.regularizers.l2(reg1)
    REG2 = tf.keras.regularizers.l2(reg2)
    DROP = 0.1

    activation = 'selu'
    inputs = Input(shape =(100,))

    x0 = Dense(64, 
              kernel_regularizer = REG1,
              activation = activation,
             )(inputs)
    

    x0 = Dropout(DROP)(x0)
    
    
    
    x2 = Dense(32, 
               kernel_regularizer = REG1,
               activation = activation,
             )(x0) 
    
    x2 = Dropout(DROP)(x2)
    
    x = Dense(1, 
                kernel_regularizer = REG2,
                activation="linear",
                )(x2)
    
    
    model = Model(inputs, x)
    

    return model

# %%
correlation_table = pd.read_csv("/ysm-gpfs/pi/zhao/tl688/openproblems/top100features_cite.csv", index_col=0)

# %%
protein_names = correlation_table.columns

# %%
protein_names
# Out:
# Index(['CD86', 'CD274', 'CD270', 'CD155', 'CD112', 'CD47', 'CD48', 'CD40',
#        'CD154', 'CD52',
#        ...
#        'CD94', 'CD162', 'CD85j', 'CD23', 'CD328', 'HLA-E', 'CD82', 'CD101',
#        'CD88', 'CD224'],
#       dtype='object', length=140)

# %%
X[correlation_table.loc[:,protein_names[0]]].values
# Out:
# array([[0.       , 0.       , 4.090185 , ..., 0.       , 6.4727488,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 0.       , 6.967164 ,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 0.       , 6.312475 ,
#         0.       ],
#        ...,
#        [0.       , 0.       , 0.       , ..., 0.       , 5.9930754,
#         0.       ],
#        [0.       , 0.       , 3.9009068, ..., 0.       , 7.0593896,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 0.       , 5.968553 ,
#         0.       ]], dtype=float32)

# %%
# model_list = []
# for i in range(len(protein_names)):
#     model_list.append(create_model())

# %%
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 100)]             0
#
#  dense_9 (Dense)             (None, 64)                6464
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 16)                1040
#
#  dropout_7 (Dropout)         (None, 16)                0
#
#  dense_11 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 7,521
# Trainable params: 7,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
X[correlation_table.loc[:,protein_names[0]]].values
# Out:
# array([[0.       , 0.       , 4.090185 , ..., 0.       , 6.4727488,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 0.       , 6.967164 ,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 0.       , 6.312475 ,
#         0.       ],
#        ...,
#        [0.       , 0.       , 0.       , ..., 0.       , 5.9930754,
#         0.       ],
#        [0.       , 0.       , 3.9009068, ..., 0.       , 7.0593896,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 0.       , 5.968553 ,
#         0.       ]], dtype=float32)

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

EPOCHS = 5
N_SPLITS = 3

pred_train = np.zeros((Y.shape[0],1))

seed_tensorflow(1)
score_list = []
kf = GroupKFold(n_splits=N_SPLITS)
# kf = sklearn.model_selection.KFold(5)
score_list = []

for fold, (idx_tr, idx_va) in enumerate(kf.split(X, groups=meta.day)):
    start_time = datetime.datetime.now()
    model = None
    gc.collect()

    for protein_index in range(140):
        X_tr = X[correlation_table.loc[:,protein_names[protein_index]]].values[idx_tr]
        y_tr = Y[idx_tr,protein_index].reshape(-1,1)
        
        X_va = X[correlation_table.loc[:,protein_names[protein_index]]].values[idx_va]
        y_va = Y[idx_va,protein_index].reshape(-1,1)

        lr = ReduceLROnPlateau(
                        monitor = "val_loss",
                        factor = 0.9, 
                        patience = 4, 
                        verbose = VERBOSE)


        es = EarlyStopping(
                        monitor = "val_loss",
                        patience = 100, 
                        verbose = VERBOSE,
                        mode = "min", 
                        restore_best_weights = True)
        
        
        checkpoint_filepath = "./citeseq_new/checkpointfile.hdf5"

        model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
                        filepath = checkpoint_filepath,
                        save_weights_only = True,
                        monitor = 'val_loss',
                        mode = 'min',
                        verbose=1,
                        save_best_only = True)

        callbacks = [   lr, 
                        es, 
                        model_checkpoint_callback
                        ]

        model = create_model()


        model.compile(
                    optimizer = tfa.optimizers.AdaBelief(learning_rate = LR_START),
                    metrics = ["mse"],
                    loss = "mse"
                     )
        # Training
        
        print("start training")
        
        model.fit( X_tr,
                    y_tr, 
                    validation_data=(
                                    X_va,
                                    y_va), 
                    epochs = EPOCHS,
                    verbose = VERBOSE,
                    batch_size = BATCH_SIZE,
                    shuffle = True,
                    callbacks = callbacks)

        del X_tr, y_tr 
        gc.collect()

        print("end training")
        
        model.load_weights(checkpoint_filepath)
        model.save(f"./submissions/model_{fold}_{protein_index}")
        print('model saved')

        #  Model validation
        y_va_pred = model.predict(X_va)
        corrscore = correlation_score(y_va, y_va_pred)
        pred_train[idx_va] = y_va_pred

        print(f"Fold {fold}, correlation =  {corrscore:.5f}")
        del X_va, y_va, y_va_pred
        gc.collect()
        score_list.append(corrscore)

# Show overall score

print(f"{Fore.GREEN}{Style.BRIGHT}Mean corr = {np.array(score_list).mean():.5f}{Style.RESET_ALL}")
score_total = correlation_score(Y, pred_train)
print(f"{Fore.BLUE}{Style.BRIGHT}Oof corr   = {score_total:.5f}{Style.RESET_ALL}")
# Out:
# start training
#
# Epoch 1: val_loss improved from inf to 0.73517, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 2: val_loss improved from 0.73517 to 0.42353, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 3: val_loss improved from 0.42353 to 0.33713, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 4: val_loss improved from 0.33713 to 0.29627, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 5: val_loss improved from 0.29627 to 0.27399, saving model to ./citeseq_new/checkpointfile.hdf5
# end training
# INFO:tensorflow:Assets written to: ./submissions/model_0_0/assets
# model saved
# 880/880 [==============================] - 1s 843us/step
# Fold 0, correlation =  nan
# start training
#
# Epoch 1: val_loss improved from inf to 1.09867, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 2: val_loss improved from 1.09867 to 0.40677, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 3: val_loss improved from 0.40677 to 0.25313, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 4: val_loss improved from 0.25313 to 0.19586, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 5: val_loss improved from 0.19586 to 0.15969, saving model to ./citeseq_new/checkpointfile.hdf5
# end training
# INFO:tensorflow:Assets written to: ./submissions/model_0_1/assets
# model saved
# 880/880 [==============================] - 1s 842us/step
# Fold 0, correlation =  nan
# start training
#
# Epoch 1: val_loss improved from inf to 1.03030, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 2: val_loss improved from 1.03030 to 0.44385, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 3: val_loss improved from 0.44385 to 0.24590, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 4: val_loss improved from 0.24590 to 0.17632, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 5: val_loss improved from 0.17632 to 0.13811, saving model to ./citeseq_new/checkpointfile.hdf5
# end training
# INFO:tensorflow:Assets written to: ./submissions/model_0_2/assets
# model saved
# 880/880 [==============================] - 1s 842us/step
# Fold 0, correlation =  nan
# start training
#
# Epoch 1: val_loss improved from inf to 0.92954, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 2: val_loss improved from 0.92954 to 0.62834, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 3: val_loss improved from 0.62834 to 0.48399, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 4: val_loss improved from 0.48399 to 0.42971, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 5: val_loss improved from 0.42971 to 0.40366, saving model to ./citeseq_new/checkpointfile.hdf5
# end training
# INFO:tensorflow:Assets written to: ./submissions/model_0_3/assets
# model saved
# 880/880 [==============================] - 1s 844us/step
# Fold 0, correlation =  nan
# start training
#
# Epoch 1: val_loss improved from inf to 0.76538, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 2: val_loss improved from 0.76538 to 0.44739, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 3: val_loss improved from 0.44739 to 0.36901, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 4: val_loss improved from 0.36901 to 0.31108, saving model to ./citeseq_new/checkpointfile.hdf5
#
# Epoch 5: val_loss improved from 0.31108 to 0.28104, saving model to ./citeseq_new/checkpointfile.hdf5
# end training
# INFO:tensorflow:Assets written to: ./submissions/model_0_4/assets
# model saved
# 880/880 [==============================] - 1s 846us/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:91
#
# Cell In [40], line 6, in correlation_score(y_true, y_pred)
#       4 corrsum = 0
#       5 for i in range(len(y_true)):
# ----> 6     corrsum += np.corrcoef(y_true[i], y_pred[i])[1, 0]
#       7 return corrsum / len(y_true)
#
# File <__array_function__ internals>:180, in corrcoef(*args, **kwargs)
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/numpy/lib/function_base.py:2859, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2854 c /= stddev[None, :]
#    2856 # Clip real and imaginary parts to [-1, 1].  This does not guarantee
#    2857 # abs(a[i,j]) <= 1 for complex arrays, but is the best we can do without
#    2858 # excessive work.
# -> 2859 np.clip(c.real, -1, 1, out=c.real)
#    2860 if np.iscomplexobj(c):
#    2861     np.clip(c.imag, -1, 1, out=c.imag)
#
# File <__array_function__ internals>:180, in clip(*args, **kwargs)
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2154, in clip(a, a_min, a_max, out, **kwargs)
#    2085 @array_function_dispatch(_clip_dispatcher)
#    2086 def clip(a, a_min, a_max, out=None, **kwargs):
#    2087     """
#    2088     Clip (limit) the values in an array.
#    2089
#    (...)
#    2152
#    2153     """
# -> 2154     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/numpy/core/_methods.py:135, in _clip(a, min, max, out, casting, **kwargs)
#     133 if not _clip_dep_is_byte_swapped(a) and not _clip_dep_is_byte_swapped(out):
#     134     using_deprecated_nan = False
# --> 135     if _clip_dep_is_scalar_nan(min):
#     136         min = -float('inf')
#     137         using_deprecated_nan = True
#
# File /gpfs/ysm/project/zhao/tl688/conda_envs/tf117/lib/python3.9/site-packages/numpy/core/_methods.py:94, in _clip_dep_is_scalar_nan(a)
#      92 def _clip_dep_is_scalar_nan(a):
#      93     # guarded to protect circular imports
# ---> 94     from numpy.core.fromnumeric import ndim
#      95     if ndim(a) != 0:
#      96         return False
#
# KeyboardInterrupt:

# %% [markdown]
# # Encode meta information into our input

# %% [markdown]
# We have some meta information in this competition, including three explicit meta information (days, donors, and cell tyoe information), and we also have one implicit meta information (gender). We can encode them into our input based on one hot encoder or embedding. The similar approach was used by JAE in the 1st open problems in single cell competition, and they won the track: joint embedding analysis.
